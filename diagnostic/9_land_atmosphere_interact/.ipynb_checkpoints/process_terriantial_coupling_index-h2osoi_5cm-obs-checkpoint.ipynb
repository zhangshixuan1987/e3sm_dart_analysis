# %%
import os
import numpy as np
import warnings 
from string import Template
import xarray as xr
import numpy as np
import pandas as pd

from scipy.stats import linregress

from datetime import datetime

from ObservationDataUtil import ( 
     ObsDataReader,
    
)
from ModelDataUtil import (
    ModelDataReader,
)

from experiment_configs import get_experiment_dict

# %%
class TerrestrialCouplingIndexCalculator:
    def __init__(self, data_dir, experiment, ensemble_list, years,
                 sm_var='SOILWATER_10CM', flux_var='LHFLX',
                 target_depth_m=None,
                 lat_bounds=None,
                 lon_bounds=None,
                 outdir='./tci_output',
                 landmask_file=None,
                 soilayer_file=None):
        self.data_dir = data_dir
        self.experiment = experiment
        self.ensemble_list = ensemble_list
        self.years = years
        self.sm_var = sm_var
        self.flux_var = flux_var
        self.lat_bounds = lat_bounds
        self.lon_bounds = lon_bounds
        self.outdir = os.path.join(outdir, experiment)
        os.makedirs(self.outdir, exist_ok=True)

        self.landmask = None
        if landmask_file and os.path.exists(landmask_file):
            self.landmask = xr.open_dataset(landmask_file)['landmask']
            self.landmask = self.normalize_longitude_and_sort(self.landmask)
            
        if soilayer_file and os.path.exists(soilayer_file):
            self.DZSOI = xr.open_dataset(soilayer_file)['DZSOI']
        else:
            self.DZSOI = None 
            
        self.Lv = 2.5e6  # J/kg
        self.expected_frequency = 'daily'

        self.regions = {
            "CONUS": {"lat": (25, 50), "lon": (-125, -65)},
            "SouthAmerica": {"lat": (-55, 15), "lon": (-80, -30)},
            "Australia": {"lat": (-45, -10), "lon": (110, 155)},
            "EastAsia": {"lat": (20, 50), "lon": (100, 140)},
            "Africa": {"lat": (-35, 35), "lon": (-20, 50)},
        }

        self.target_depth_m = target_depth_m
        
    def normalize_longitude_and_sort(self, ds, lon_name='lon'):
        """
        Normalize longitude in the dataset to [-180, 180] and sort by longitude.
    
        Parameters
        ----------
        ds : xr.DataArray or xr.Dataset
            Input data with a longitude coordinate.
        lon_name : str, default='lon'
            Name of the longitude coordinate.
    
        Returns
        -------
        xr.DataArray or xr.Dataset
            Dataset with normalized and sorted longitude.
        """
        if lon_name in ds.coords:
            lon = ds[lon_name]
            if lon.max() > 180:
                print("[INFO] Normalizing longitude to [-180, 180].")
                ds[lon_name] = ((lon + 180) % 360) - 180
                ds = ds.sortby(lon_name)
        return ds
    
    def compute_layer_integrated_sm(self, h2osoi, dzsoi, target_depth):
        if target_depth is not None: 
            dz_cumsum = dzsoi.cumsum(dim='levgrnd')
            mask = dz_cumsum <= target_depth
            h2osoi_masked = h2osoi.where(mask, 0.0)
            dzsoi_masked = dzsoi.where(mask, 0.0)
            sm = (h2osoi_masked * dzsoi_masked).sum(dim="levgrnd")
        else:
            sm = (h2osoi * dzsoi).sum(dim="levgrnd")
        sm = sm * 1000.0
        sm.attrs["units"] = "kg/m2"
        # Remove singleton lev dimension if present
        if 'levgrnd' in sm.dims and sm.sizes['levgrnd'] == 1:
            sm = sm.squeeze(dim='levgrnd')
        return sm

    def _resample_if_needed(self, ds):
        if self.expected_frequency.lower() == '6h':
            print("[INFO] Resampling 6-hourly data to daily means...")
            ds_daily = ds.resample(time='1D').mean()
            
            # Normalize time to start-of-day (00:00)
            ds_daily['time'] = pd.to_datetime(ds_daily['time'].values).normalize()
            return ds_daily
        return ds

    def _load_variable(self, varname, ensemble):
        original_var = varname
        possible_vars = [varname]
        if varname == "LHFLX":
            possible_vars = ["LHFLX", "QFLX"]

        if varname in ["SOILWATER_10CM", "H2OSOI"]:
            data_dir = self.data_dir.replace('atm', 'lnd')
        else:
            data_dir = self.data_dir

        alt_dir = data_dir.replace("daily", "6hourly")

        for v in possible_vars:
            for base_dir in [data_dir, alt_dir]:
                files = [os.path.join(base_dir, f"{v}.{ensemble}.{year}.nc") for year in self.years]
                if all(os.path.exists(f) for f in files):
                    if base_dir == alt_dir:
                        self.expected_frequency = '6h'
                        print(f"[INFO] {v} found in 6-hourly path: resampling will be applied.")

                    if original_var == "H2OSOI":
                        h2osoi = xr.concat([xr.open_dataset(f)["H2OSOI"] for f in files], dim="time")
                        h2osoi = self._resample_if_needed(h2osoi)
                        dzsoi = self.DZSOI 
                        sm = self.compute_layer_integrated_sm(h2osoi, dzsoi, self.target_depth_m)
                        if self.target_depth_m:
                            sm.name = f"SM_{int(self.target_depth_m * 100)}cm"
                        else:
                            sm.name = "SM_total"
                        ds = sm
                    else:
                        datasets = [xr.open_dataset(f)[v] for f in files]
                        ds = xr.concat(datasets, dim='time')
                        ds = self._resample_if_needed(ds)
                            
                    coord_renames = {}
                    for coord in ds.coords:
                        if coord.lower() == 'longitude':
                            coord_renames[coord] = 'lon'
                        elif coord.lower() == 'latitude':
                            coord_renames[coord] = 'lat'
                    if coord_renames:
                        print(f"[INFO] Renaming coordinates: {coord_renames}")
                        ds = ds.rename(coord_renames)
                        
                    ds = self.normalize_longitude_and_sort(ds)
                            
                    if self.landmask is not None and 'lat' in ds.coords and 'lon' in ds.coords:
                        try:
                            print("[INFO] Applying landmask...")
                            mask_interp = self.landmask.interp_like(ds, method='nearest')
                            ds = ds.where(mask_interp > 0.5)
                        except Exception as e:
                            print(f"[WARN] Failed to apply landmask: {e}")

                    if original_var == "LHFLX" and v == "QFLX":
                        print("[INFO] Converting QFLX to LHFLX using Lv.")
                        ds = ds * self.Lv
                        ds.attrs["units"] = "W/m2"
                        ds.name = "LHFLX"
                            
                    if self.lat_bounds:
                        ds = ds.sel(lat=slice(*self.lat_bounds))
                    if self.lon_bounds:
                        ds = ds.sel(lon=slice(*self.lon_bounds))

                    return ds

        raise FileNotFoundError(f"[ERROR] Could not find {possible_vars} in {data_dir} or {alt_dir} for {ensemble}.")
        
    def _compute_tci_dirmeyer(self, sm, flux):
        # Align by common time steps
        common_time = np.intersect1d(sm['time'], flux['time'])
        if len(common_time) < 2:
            raise ValueError("[ERROR] Not enough overlapping time points for regression.")
        
        sm = sm.sel(time=common_time)
        flux = flux.sel(time=common_time)
    
        # Stack spatial dims
        sm_stack = sm.stack(grid=('lat', 'lon')).transpose('time', 'grid')
        flux_stack = flux.stack(grid=('lat', 'lon')).transpose('time', 'grid')
    
        tci_vals = []
        for i in range(sm_stack.shape[1]):
            x = sm_stack[:, i].values
            y = flux_stack[:, i].values
            if (
                np.all(np.isfinite(x)) and
                np.all(np.isfinite(y)) and
                x.size > 1 and
                not np.allclose(x, x[0])
            ):
                slope, _, _, _, _ = linregress(x, y)
                sigma = np.std(x)
                tci_vals.append(slope * sigma)
            else:
                tci_vals.append(np.nan)
    
        tci_array = np.array(tci_vals).reshape((sm.sizes['lat'], sm.sizes['lon']))
        return xr.DataArray(
            tci_array, coords={'lat': sm.lat, 'lon': sm.lon},
            dims=['lat', 'lon'], name='TCI'
        )

    def compute_weighted_mean(self, tci_all):
        weights = np.cos(np.deg2rad(tci_all['lat']))
        weights.name = "weights"
        return tci_all.weighted(weights).mean(dim=['lat', 'lon'], skipna=True)

    def save_regional_mean(self, tci_all, tag, ens):
        data_vars = {}
    
        for region, bounds in self.regions.items():
            if bounds['lon'][0] < bounds['lon'][1]:
                tci_region = tci_all.sel(
                    lat=slice(*bounds['lat']),
                    lon=slice(*bounds['lon'])
                )
            else:
                west = tci_all.sel(lon=slice(bounds['lon'][0], 180))
                east = tci_all.sel(lon=slice(-180, bounds['lon'][1]))
                tci_region = xr.concat([west, east], dim='lon')
    
            mean_tci = self.compute_weighted_mean(tci_region)
            data_vars[f"TCI_{region}"] = mean_tci
    
        # Create a dataset with all regional means
        ds_out = xr.Dataset(data_vars)
    
        # Construct sub-identifier
        if self.sm_var == 'H2OSOI':
            if self.target_depth_m:
                sub = f"{self.sm_var}_{int(self.target_depth_m * 100)}cm_{self.flux_var}"
            else:
                sub = f"{self.sm_var}_alllayer_{self.flux_var}"
        else:
            sub = f"{self.sm_var}_{self.flux_var}"
    
        # Save one file with all regions
        outfile = os.path.join(self.outdir, f"TCI_window_{tag}_{ens}_{sub}_regional_mean.nc")
        ds_out.to_netcdf(outfile)
        print(f"[SAVED] All regional means: {outfile}")

    def process(self, windows_dict, compute_regional_mean=False):
        for ens in self.ensemble_list:
            print(f"[INFO] Processing {self.experiment} | {ens}")
            sm = self._load_variable(self.sm_var, ens)
            flux = self._load_variable(self.flux_var, ens)

            if not np.issubdtype(sm['time'].dtype, np.datetime64):
                base_time = np.datetime64(f"{self.years[0]}-01-01")
                sm['time'] = base_time + xr.to_timedelta(sm['time'], unit='h')
                flux['time'] = sm['time']

            for tag, (start_str, end_str) in windows_dict.items():
                start = np.datetime64(start_str)
                end = np.datetime64(end_str)

                sm_window = sm.sel(time=slice(start, end))
                flux_window = flux.sel(time=slice(start, end))

                if sm_window.time.size < 2:
                    print(f"[WARN] Not enough data for window {tag}")
                    continue

                tci = self._compute_tci_dirmeyer(sm_window, flux_window)
                tci['time'] = sm_window.time.mean()
                tci = tci.expand_dims('time')

                sub_tag = (
                    f"{self.sm_var}_{int(self.target_depth_m * 100)}cm_{self.flux_var}"
                    if self.sm_var == "H2OSOI" and self.target_depth_m
                    else f"{self.sm_var}_{self.flux_var}"
                )

                file_out = os.path.join(self.outdir, f"TCI_window_{tag}_{ens}_{sub_tag}.nc")
                tci.to_netcdf(file_out)
                print(f"[SAVED] {file_out}")

                if compute_regional_mean:
                    self.save_regional_mean(tci, tag, ens)

# %%
if __name__ == "__main__":
    top_path = "/pscratch/sd/z/zhan391/e3sm_dart"
    out_path = "/pscratch/sd/z/zhan391/e3sm_dart/diag_dart"
    fig_path = "/people/zhan391/e3sm_dart_work/analysis/diagnostic/figures"
    landmask_file = "/pscratch/sd/z/zhan391/e3sm_dart/diag_dart/landmask_1x1.nc"
    soilayer_file = "/pscratch/sd/z/zhan391/e3sm_dart/diag_dart/dzsoi_elm.nc"

    exp_key = {
        "v3_spinup": 2011,
        "v3_hindcast": 2012
    }
    exp = 'v3_hindcast'
    exp_dict = get_experiment_dict(exp)
    years = [exp_key[exp]]

    # Labeled windows for TCI
    windows_dict = {
        "D1-15":   ("2012-01-01", "2012-01-15"),
        "D16-30":  ("2012-01-16", "2012-01-30"),
        "D31-45":  ("2012-01-31", "2012-02-14"),
        "D46-60":  ("2012-02-15", "2012-03-01"),
        "2012-01":  ("2012-01-01", "2012-01-31"),
        "2012-02":  ("2012-02-01", "2012-02-29")
    }
    
    for exp_name, exp_meta in exp_dict.items():
        print(f"\n[INFO] Running TCI for experiment: {exp_name}")
        path = exp_meta['path']
        template_str = exp_meta['template']
        template = Template(template_str.replace('%(', '${').replace(')s', '}'))
        nens = exp_meta['nens']
        ensemble_list = [f"EN{n:02d}" for n in range(1, nens + 1)]

        tci_calc = TerrestrialCouplingIndexCalculator(
            data_dir=path,
            experiment=exp_name,
            ensemble_list=ensemble_list,
            years=years,
            sm_var='H2OSOI',
            flux_var='LHFLX',
            target_depth_m=0.05,
            outdir=out_path,
            landmask_file=landmask_file,
            soilayer_file=soilayer_file
        )

        tci_calc.process(windows_dict=windows_dict, compute_regional_mean=True)
# Out:
# [INFO] Running TCI for experiment: CTRLEN10
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Processing CTRLEN10 | EN01
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CTRLEN10 | EN02
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CTRLEN10 | EN03
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CTRLEN10 | EN04
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CTRLEN10 | EN05
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CTRLEN10 | EN06
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CTRLEN10 | EN07
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CTRLEN10 | EN08
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CTRLEN10 | EN09
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CTRLEN10 | EN10
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D1-15_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D16-30_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D31-45_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_D46-60_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-01_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CTRLEN10/TCI_window_2012-02_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
#
# [INFO] Running TCI for experiment: CAPTEN10
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Processing CAPTEN10 | EN01
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CAPTEN10 | EN02
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CAPTEN10 | EN03
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CAPTEN10 | EN04
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CAPTEN10 | EN05
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN05_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN05_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CAPTEN10 | EN06
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN06_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN06_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CAPTEN10 | EN07
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN07_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN07_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CAPTEN10 | EN08
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN08_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN08_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CAPTEN10 | EN09
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN09_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN09_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing CAPTEN10 | EN10
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D1-15_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D16-30_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D31-45_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_D46-60_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-01_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/CAPTEN10/TCI_window_2012-02_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
#
# [INFO] Running TCI for experiment: DARTEN20
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Processing DARTEN20 | EN01
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN01_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN01_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN02
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN02_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN02_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN03
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN03_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN03_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN04
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN04_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN04_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN10_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN10_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN11
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN11_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN11_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN11_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN11_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN11_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN11_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN11_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN11_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN11_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN11_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN11_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN11_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN12
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN12_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN12_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN12_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN12_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN12_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN12_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN12_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN12_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN12_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN12_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN12_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN12_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN13
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN13_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN13_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN13_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN13_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN13_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN13_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN13_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN13_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN13_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN13_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN13_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN13_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN14
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN14_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN14_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN14_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN14_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN14_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN14_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN14_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN14_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN14_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN14_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN14_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN14_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN15
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN15_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN15_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN15_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN15_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN15_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN15_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN15_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN15_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN15_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN15_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN15_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN15_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN16
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN16_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN16_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN16_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN16_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN16_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN16_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN16_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN16_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN16_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN16_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN16_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN16_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN17
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN17_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN17_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN17_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D16-30_EN17_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN17_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D31-45_EN17_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN17_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D46-60_EN17_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN17_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-01_EN17_H2OSOI_5cm_LHFLX_regional_mean.nc
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN17_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_2012-02_EN17_H2OSOI_5cm_LHFLX_regional_mean.nc
# [INFO] Processing DARTEN20 | EN18
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [INFO] LHFLX found in 6-hourly path: resampling will be applied.
# [INFO] Resampling 6-hourly data to daily means...
# [INFO] Normalizing longitude to [-180, 180].
# [INFO] Applying landmask...
# [SAVED] /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN18_H2OSOI_5cm_LHFLX.nc
# [SAVED] All regional means: /pscratch/sd/z/zhan391/e3sm_dart/diag_dart/DARTEN20/TCI_window_D1-15_EN18_H2OSOI_5cm_LHFLX_regional_mean.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 47
#      32 ensemble_list = [f"EN{n:02d}" for n in range(1, nens + 1)]
#      34 tci_calc = TerrestrialCouplingIndexCalculator(
#      35     data_dir=path,
#      36     experiment=exp_name,
#    (...)
#      44     soilayer_file=soilayer_file
#      45 )
# ---> 47 tci_calc.process(windows_dict=windows_dict, compute_regional_mean=True)
#
# Cell In[8], line 261, in TerrestrialCouplingIndexCalculator.process(self, windows_dict, compute_regional_mean)
#     258     print(f"[WARN] Not enough data for window {tag}")
#     259     continue
# --> 261 tci = self._compute_tci_dirmeyer(sm_window, flux_window)
#     262 tci['time'] = sm_window.time.mean()
#     263 tci = tci.expand_dims('time')
#
# Cell In[8], line 181, in TerrestrialCouplingIndexCalculator._compute_tci_dirmeyer(self, sm, flux)
#     179 for i in range(sm_stack.shape[1]):
#     180     x = sm_stack[:, i].values
# --> 181     y = flux_stack[:, i].values
#     182     if (
#     183         np.all(np.isfinite(x)) and
#     184         np.all(np.isfinite(y)) and
#     185         x.size > 1 and
#     186         not np.allclose(x, x[0])
#     187     ):
#     188         slope, _, _, _, _ = linregress(x, y)
#
# File ~/.local/lib/python3.10/site-packages/xarray/core/dataarray.py:891, in DataArray.__getitem__(self, key)
#     888     return self._getitem_coord(key)
#     889 else:
#     890     # xarray-style array indexing
# --> 891     return self.isel(indexers=self._item_key_to_dict(key))
#
# File ~/.local/lib/python3.10/site-packages/xarray/core/dataarray.py:1539, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1535 coord_indexers = {
#    1536     k: v for k, v in indexers.items() if k in coord_value.dims
#    1537 }
#    1538 if coord_indexers:
# -> 1539     coord_value = coord_value.isel(coord_indexers)
#    1540     if drop and coord_value.ndim == 0:
#    1541         continue
#
# File ~/.local/lib/python3.10/site-packages/xarray/core/variable.py:1034, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1031 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1033 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1034 return self[key]
#
# File ~/.local/lib/python3.10/site-packages/xarray/core/variable.py:805, in Variable.__getitem__(self, key)
#     803 if new_order:
#     804     data = np.moveaxis(data, range(len(new_order)), new_order)
# --> 805 return self._finalize_indexing_result(dims, data)
#
# File ~/.local/lib/python3.10/site-packages/xarray/core/variable.py:2682, in IndexVariable._finalize_indexing_result(self, dims, data)
#    2679 def _finalize_indexing_result(self, dims, data):
#    2680     if getattr(data, "ndim", 0) != 1:
#    2681         # returns Variable rather than IndexVariable if multi-dimensional
# -> 2682         return Variable(dims, data, self._attrs, self._encoding)
#    2683     else:
#    2684         return self._replace(dims=dims, data=data)
#
# File ~/.local/lib/python3.10/site-packages/xarray/core/variable.py:399, in Variable.__init__(self, dims, data, attrs, encoding, fastpath)
#     371 def __init__(
#     372     self,
#     373     dims,
#    (...)
#     377     fastpath=False,
#     378 ):
#     379     """
#     380     Parameters
#     381     ----------
#    (...)
#     396         unrecognized encoding items.
#     397     """
#     398     super().__init__(
# --> 399         dims=dims, data=as_compatible_data(data, fastpath=fastpath), attrs=attrs
#     400     )
#     402     self._encoding = None
#     403     if encoding is not None:
#
# File ~/.local/lib/python3.10/site-packages/xarray/core/variable.py:321, in as_compatible_data(data, fastpath)
#     318 data = np.asarray(data)
#     320 if isinstance(data, np.ndarray) and data.dtype.kind in "OMm":
# --> 321     data = _possibly_convert_objects(data)
#     322 return _maybe_wrap_data(data)
#
# File ~/.local/lib/python3.10/site-packages/xarray/core/variable.py:233, in _possibly_convert_objects(values)
#     221 def _possibly_convert_objects(values):
#     222     """Convert arrays of datetime.datetime and datetime.timedelta objects into
#     223     datetime64 and timedelta64, according to the pandas convention. For the time
#     224     being, convert any non-nanosecond precision DatetimeIndex or TimedeltaIndex
#    (...)
#     231     if they are not.
#     232     """
# --> 233     as_series = pd.Series(values.ravel(), copy=False)
#     234     if as_series.dtype.kind in "mM":
#     235         as_series = _as_nanosecond_precision(as_series)
#
# File /global/common/software/e3sm/anaconda_envs/base/envs/e3sm_unified_1.10.0_login/lib/python3.10/site-packages/pandas/core/series.py:588, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     586 manager = _get_option("mode.data_manager", silent=True)
#     587 if manager == "block":
# --> 588     data = SingleBlockManager.from_array(data, index, refs=refs)
#     589 elif manager == "array":
#     590     data = SingleArrayManager.from_array(data, index)
#
# File /global/common/software/e3sm/anaconda_envs/base/envs/e3sm_unified_1.10.0_login/lib/python3.10/site-packages/pandas/core/internals/managers.py:1870, in SingleBlockManager.from_array(cls, array, index, refs)
#    1863 @classmethod
#    1864 def from_array(
#    1865     cls, array: ArrayLike, index: Index, refs: BlockValuesRefs | None = None
#    1866 ) -> SingleBlockManager:
#    1867     """
#    1868     Constructor for if we have an array that is not yet a Block.
#    1869     """
# -> 1870     array = maybe_coerce_values(array)
#    1871     bp = BlockPlacement(slice(0, len(index)))
#    1872     block = new_block(array, placement=bp, ndim=1, refs=refs)
#
# File /global/common/software/e3sm/anaconda_envs/base/envs/e3sm_unified_1.10.0_login/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2662, in maybe_coerce_values(values)
#    2659 # Caller is responsible for ensuring NumpyExtensionArray is already extracted.
#    2661 if isinstance(values, np.ndarray):
# -> 2662     values = ensure_wrapped_if_datetimelike(values)
#    2664     if issubclass(values.dtype.type, str):
#    2665         values = np.array(values, dtype=object)
#
# File /global/common/software/e3sm/anaconda_envs/base/envs/e3sm_unified_1.10.0_login/lib/python3.10/site-packages/pandas/core/construction.py:486, in ensure_wrapped_if_datetimelike(arr)
#     482 """
#     483 Wrap datetime64 and timedelta64 ndarrays in DatetimeArray/TimedeltaArray.
#     484 """
#     485 if isinstance(arr, np.ndarray):
# --> 486     if arr.dtype.kind == "M":
#     487         from pandas.core.arrays import DatetimeArray
#     489         dtype = get_supported_dtype(arr.dtype)
#
# KeyboardInterrupt:
