# %%
import os
import numpy as np
import warnings 

from datetime import datetime

from ObservationDataUtil import ( 
     ObsDataReader,
    
)
from ModelDataUtil import (
    ModelDataReader,
    EnsembleMetricEvaluator
)

# %%
if __name__ == "__main__":
    top_path = "/compyfs/zhan391/v3_dart_cda_scratch"
    out_path = "/compyfs/zhan391/v3_dart_cda_scratch/diag_dart"
    fig_path = "/qfs/people/zhan391/e3sm_dart_work/analysis/diagnostic/figures"

    compset = "F20TR"
    resolution = "ne30pg2_r05_IcoswISC30E3r5"
    machine = "compy"
    exp_base = f"{compset}_{resolution}_{machine}"

    regnam = "global"
    plot_type = "model_vs_obs"
    period = "2011-12"  # monthly format
    frequency = "monthly"

    # === Variable dictionary ===
    var_dict = {
        'TS':     {'alias': 'TS',   'unit': '$^o$C', 'level': np.linspace(-8, 8, 51),  'comp': 'atm', 'ref': "ERA5"},
        'TSA':    {'alias': 'T2M',  'unit': '$^o$C', 'level': np.linspace(-10, 10, 51), 'comp': 'lnd', 'ref': "MODIS_LST"},        
        'TREFHT': {'alias' : 'TREFHT', 'unit': '$^o$C',         'level': np.linspace(-8, 8, 51),  'comp': 'atm', 'ref': "ERA5"},
        'PRECT':  {'alias' : 'PRECT',  'unit': 'mm day$^{-1}$', 'level': np.linspace(-2, 2, 51),  'comp': 'atm', 'ref': "ERA5"},
        'PSL':    {'alias' : 'PSL',    'unit': 'hPa',           'level': np.linspace(-10, 10, 51),'comp': 'atm', 'ref': "ERA5"},
        'TMQ':    {'alias' : 'TMQ',    'unit': 'kg m$^{-2}$',   'level': np.linspace(-10, 10, 51),'comp': 'atm', 'ref': "ERA5"},
        'FLUT':   {'alias' : 'FLUT',   'unit': 'W m$^{-2}$',    'level': np.linspace(-10, 10, 51),'comp': 'atm', 'ref': "CERES-OAFlux"},
        'TSA':    {'alias' : 'T2M',    'unit': '$^o$C',         'level': np.linspace(-10, 10, 51),'comp': 'lnd', 'ref': "MODIS_LST"},
        'H2OSOI': {'alias' :'H2OSOI',  'unit':'mm',             'level': np.linspace(-10, 10, 51),'comp': 'lnd', 'ref': "ESA_CCI"},
        'SOILWATER_10CM':{'alias':'SOILWATER_10CM','unit':'mm', 'level': np.linspace(-10, 10, 51),'comp': 'lnd', 'ref': "CPC_SOM"},
    }

    model_labels = {
        'CTRLEN10': "CTRL (ENS=10)",
        'DARTEN10': "EAM-DART (ENS=10)",
        'DARTEN20': "EAM-DART (ENS=20)",
        'DARTEN40': "EAM-DART (ENS=40)",
        'DARTEN80': "EAM-DART (ENS=80)",
    }

    model_list = ['CTRLEN10', 'DARTEN20', 'DARTEN40']

    # Ensure output path exists
    os.makedirs(out_path, exist_ok=True)

    # Optional: save run configuration for reproducibility
    config_file = os.path.join(out_path, "diagnostic_run_config.txt")
    with open(config_file, "w") as f:
        f.write(f"Run Time: {datetime.now().isoformat()}\n")
        f.write(f"Variables: {list(var_dict.keys())}\n")
        f.write(f"Models: {model_list}\n")
        f.write(f"Region: {regnam}, Period: {period}, Frequency: {frequency}\n")
        f.write(f"Experiment Base: {exp_base}\n")

    # === Loop over variables ===
    for var, meta in var_dict.items():
        try:
            print(f"[{datetime.now().isoformat()}] Processing {var} using {meta['ref']}")

            component = meta.get('comp', 'atm')
            ref_var = meta.get('alias', var)
            ref_dataset = meta.get('ref', 'ERA5')

            # Load observational reference
            obs = ObsDataReader().read(
                var=ref_var,
                obsname=ref_dataset,
                time=period,
                frequency=frequency
            )

            # Load model ensemble data
            model_reader = ModelDataReader(
                base_path=top_path,
                exp_base=exp_base,
                regnam=regnam,
                frequency=frequency,
                period=period,
                component=component
            )
            data_dict = model_reader.read_variable_across_experiments(var, model_list)

            # Evaluate metrics and save
            evaluator = EnsembleMetricEvaluator(
                obs=obs,
                model_dict=data_dict,
                component=component,
                ref_dataset=ref_dataset,
                var=var,
                vunit=meta['unit'],
                output_path=out_path
            )

        except Exception as e:
            print(f"[ERROR] Failed to process {var}: {e}")
# Out:
# [2025-06-06T01:45:53.529438] Processing TS using ERA5
# [ERROR] Failed to process TS: name 'ObsDataReader' is not defined
# [2025-06-06T01:45:53.529613] Processing TSA using MODIS_LST
# [ERROR] Failed to process TSA: name 'ObsDataReader' is not defined
# [2025-06-06T01:45:53.529658] Processing TREFHT using ERA5
# [ERROR] Failed to process TREFHT: name 'ObsDataReader' is not defined
# [2025-06-06T01:45:53.529693] Processing PRECT using ERA5
# [ERROR] Failed to process PRECT: name 'ObsDataReader' is not defined
# [2025-06-06T01:45:53.529727] Processing PSL using ERA5
# [ERROR] Failed to process PSL: name 'ObsDataReader' is not defined
# [2025-06-06T01:45:53.529758] Processing TMQ using ERA5
# [ERROR] Failed to process TMQ: name 'ObsDataReader' is not defined
# [2025-06-06T01:45:53.529792] Processing FLUT using CERES-OAFlux
# [ERROR] Failed to process FLUT: name 'ObsDataReader' is not defined
# [2025-06-06T01:45:53.529824] Processing H2OSOI using ESA_CCI
# [ERROR] Failed to process H2OSOI: name 'ObsDataReader' is not defined
# [2025-06-06T01:45:53.529854] Processing SOILWATER_10CM using CPC_SOM
# [ERROR] Failed to process SOILWATER_10CM: name 'ObsDataReader' is not defined
